# %% [markdown]
# ### Validation

# %%
import platform

import pandas as pd
import numpy as np
import scipy

import sklearn
import statsmodels.api as sm
import xgboost as xgb
import torch

import matplotlib
import matplotlib.pyplot as plt
import plotly

# %%
import typing as t

import pandas as pd
import numpy as np


def submit_answer_2(filled_df: pd.DataFrame) -> None:
    masked_df = pd.read_csv("limestone_data_challenge_2026.data.csv")

    assert sorted(masked_df.columns) == sorted(filled_df.columns)
    assert np.all(masked_df["time"] == filled_df["time"])

    filled_df.fillna(0).to_csv(
        "modelling_prices.submission.2.csv",
        index=False
    )

# %% [markdown]
# ### Workspace

# %%
import typing as t
import pandas as pd


def placeholder_example_solution_for_format() -> pd.DataFrame:
    df = pd.read_csv("limestone_data_challenge_2026.data.csv")
    answer_to_validate_format = df.fillna(value=0)
    return answer_to_validate_format


submit_answer_2(placeholder_example_solution_for_format())  # You must submit your own final answer.
